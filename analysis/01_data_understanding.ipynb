# %%
df = pd.read_excel(
    "../data/raw/Indian_Student_Placement_Dataset_2025.xlsx"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_excel(
#       2     "../data/raw/Indian_Student_Placement_Dataset_2025.xlsx"
#       3 )
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_excel(
    "../data/raw/Indian_Student_Placement_Dataset_2025.xlsx"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_excel(
#       2     "../data/raw/Indian_Student_Placement_Dataset_2025.xlsx"
#       3 )
#
# File c:\Users\Srushti\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
import pandas as pd

df = pd.read_excel(
    "../data/raw/Indian_Student_Placement_Dataset_2025.xlsx",
    engine="openpyxl"
)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel(
#       4     "../data/raw/Indian_Student_Placement_Dataset_2025.xlsx",
#       5     engine="openpyxl"
#       6 )
#
# File c:\Users\Srushti\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
import pandas as pd

df = pd.read_excel(
    "../data/raw/Student_Placement_Dataset_2025.xlsx",
    engine="openpyxl"
)

# %%
df.head()
# Out:
#   student_id,gender,age,degree,branch,cgpa,backlogs,internships,certifications,coding_skills,communication_skills,aptitude_score,projects,placed,company_type,package_lpa
# 0  1,Male,20,BE,Mechanical,8.4,2,2,2,1,3,69,0,0,N...
# 1  2,Female,20,BTech,Electrical,8.6,2,0,5,1,9,81,...
# 2  3,Male,22,BCA,Electrical,6.62,3,0,1,1,7,50,1,0...
# 3    4,Male,24,BCA,DS,8.01,0,0,4,4,7,47,4,0,None,0.0
# 4  5,Male,24,BCA,Electrical,9.12,2,1,2,4,4,77,4,0...

# %%
df.shape
# Out:
# (12000, 1)

# %%
df.iloc[0, 0]
# Out:
# '1,Male,20,BE,Mechanical,8.4,2,2,2,1,3,69,0,0,None,0.0'

# %%
df.columns.tolist()
# Out:
# ['student_id,gender,age,degree,branch,cgpa,backlogs,internships,certifications,coding_skills,communication_skills,aptitude_score,projects,placed,company_type,package_lpa']
